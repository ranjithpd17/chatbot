# %%
import tensorflow

# %%
import keras

# %%
import nltk

# %%
import pickle

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\.conda\envs\tensorflow\lib\site-packages\nltk\corpus\util.py in __load(self)
#      82                 try:
# ---> 83                     root = nltk.data.find("{}/{}".format(self.subdir, zip_name))
#      84                 except LookupError:
#
# ~\.conda\envs\tensorflow\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - 'C:\\Users\\Deepu/nltk_data'
#     - 'C:\\Users\\Deepu\\.conda\\envs\\tensorflow\\nltk_data'
#     - 'C:\\Users\\Deepu\\.conda\\envs\\tensorflow\\share\\nltk_data'
#     - 'C:\\Users\\Deepu\\.conda\\envs\\tensorflow\\lib\\nltk_data'
#     - 'C:\\Users\\Deepu\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3340/269566434.py in <module>
#       1 # lemmatize, lower each word and remove duplicates
# ----> 2 words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
#       3 words = sorted(list(set(words)))
#       4 # sort classes
#       5 classes = sorted(list(set(classes)))
#
# ~\AppData\Local\Temp/ipykernel_3340/269566434.py in <listcomp>(.0)
#       1 # lemmatize, lower each word and remove duplicates
# ----> 2 words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
#       3 words = sorted(list(set(words)))
#       4 # sort classes
#       5 classes = sorted(list(set(classes)))
#
# ~\.conda\envs\tensorflow\lib\site-packages\nltk\stem\wordnet.py in lemmatize(self, word, pos)
#      36
#      37     def lemmatize(self, word, pos=NOUN):
# ---> 38         lemmas = wordnet._morphy(word, pos)
#      39         return min(lemmas, key=len) if lemmas else word
#      40
#
# ~\.conda\envs\tensorflow\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     118             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     119
# --> 120         self.__load()
#     121         # This looks circular, but its not, since __load() changes our
#     122         # __class__ to something new:
#
# ~\.conda\envs\tensorflow\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                     root = nltk.data.find("{}/{}".format(self.subdir, zip_name))
#      84                 except LookupError:
# ---> 85                     raise e
#      86
#      87         # Load the corpus.
#
# ~\.conda\envs\tensorflow\lib\site-packages\nltk\corpus\util.py in __load(self)
#      78         else:
#      79             try:
# ---> 80                 root = nltk.data.find("{}/{}".format(self.subdir, self.__name))
#      81             except LookupError as e:
#      82                 try:
#
# ~\.conda\envs\tensorflow\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - 'C:\\Users\\Deepu/nltk_data'
#     - 'C:\\Users\\Deepu\\.conda\\envs\\tensorflow\\nltk_data'
#     - 'C:\\Users\\Deepu\\.conda\\envs\\tensorflow\\share\\nltk_data'
#     - 'C:\\Users\\Deepu\\.conda\\envs\\tensorflow\\lib\\nltk_data'
#     - 'C:\\Users\\Deepu\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Deepu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\Deepu\AppData\Local\Temp/ipykernel_3340/2836083368.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# Epoch 1/200
#  2/10 [=====>........................] - ETA: 0s - loss: 2.1995 - accuracy: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.0050s). Check your callbacks.
# 10/10 [==============================] - 0s 11ms/step - loss: 2.2050 - accuracy: 0.1277
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1505 - accuracy: 0.1064
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.0118 - accuracy: 0.2553
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9588 - accuracy: 0.2979
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8932 - accuracy: 0.3191
# Epoch 6/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.7674 - accuracy: 0.3617
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6885 - accuracy: 0.4468
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5121 - accuracy: 0.4255
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4154 - accuracy: 0.5745
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2348 - accuracy: 0.6170
# Epoch 11/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1614 - accuracy: 0.7021
# Epoch 12/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1824 - accuracy: 0.6596
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0470 - accuracy: 0.6170
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8618 - accuracy: 0.8085
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9094 - accuracy: 0.6809
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8890 - accuracy: 0.6596
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7429 - accuracy: 0.7447
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6822 - accuracy: 0.7447
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6778 - accuracy: 0.7234
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5143 - accuracy: 0.8511
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.8085
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5265 - accuracy: 0.7872
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5677 - accuracy: 0.8085
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.9362
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4515 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.9149
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3654 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 1.00 - 0s 2ms/step - loss: 0.3534 - accuracy: 0.9149
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4029 - accuracy: 0.8511
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4322 - accuracy: 0.8723
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3244 - accuracy: 0.9787
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.9149
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4195 - accuracy: 0.9149
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2634 - accuracy: 0.8936
# Epoch 36/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2911 - accuracy: 0.9149
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0851 - accuracy: 1.0000
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1426 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2012 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1281 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9787
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2142 - accuracy: 0.9362
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.9574
# Epoch 45/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 1.0000
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1201 - accuracy: 0.9574
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2396 - accuracy: 0.9149
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2071 - accuracy: 0.9574
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9362
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1064 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9787
# Epoch 54/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0602 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9574
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0672 - accuracy: 0.9787
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0765 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0666 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1055 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1310 - accuracy: 0.9574
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0684 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1438 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9574
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9787
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0884 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9787
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1043 - accuracy: 0.9574
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0608 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9574
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9787
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9787
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.9574
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9787
# Epoch 127/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9574
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0541 - accuracy: 0.9787
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0679 - accuracy: 0.9574
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9574
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9787
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9787
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9787
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
